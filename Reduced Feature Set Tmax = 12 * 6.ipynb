# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas
import xarray
import cftime
import tensorflow as tf
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
# Out:
# /Users/paulag/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
datapath = 'nino34_monthly.nc'
nino34 = xarray.open_dataset(datapath, decode_times = False)
nino34 = np.array((nino34['nino34'].values)[12 * 50:])

# %%
def ONI(nino34, m = 3):
    oni = np.array(nino34)
    length = nino34.shape[0]
    for i in range(length):
        oni[i] = np.mean(nino34[max(0, (i - m + 1)) : min((i + 1), length)])
    return oni

# %%
oni = ONI(nino34)

# %%
def climatology(nino34):
    clm = np.zeros(12)
    length = nino34.shape[0]
    for month in range(12):
        section = [12 * i + month for i in range(length // 12)]
        clm[month] = np.mean(nino34[section])
    return clm

# %%
clm = climatology(nino34)

# %%
def SST_anomaly(nino34, clm):
    anm = np.array(nino34)
    length = nino34.shape[0]
    for i in range(length):
        anm[i] = nino34[i] - clm[i % 12]
    return anm

# %%
anm = SST_anomaly(nino34, clm)
oanm = ONI(anm)

# %%
T = 12 * 6  # prediction timeline
H = 3   # history used for prediction
Hmax = 24
extra_features = 4 # running mean of 6/12/24 + month

signal = np.array(nino34)   # data used for training/testing
length = signal.shape[0]    # number of data points

mean = np.mean(signal)
std = np.std(signal)

signal = (signal - mean) / std

# %%
np.random.seed(0)

size = length - H - T       # effective dataset size
        
# create the 'history matrix'
data = np.ndarray((size, H + extra_features))
for i in range(size):
    data[i, 0:H] = signal[i:(i + H)]
    data[i, H] = np.mean(signal[i:(i + 6)])
    data[i, H+1] = np.mean(signal[i:(i + 6 * 2)])
    data[i, H+2] = np.mean(signal[i:(i + 6 * 4)])
    data[i, H+3] = ((i + H) % 12 - np.mean(range(12))) / np.std(range(12))
    

labels = np.ndarray((size, T), dtype = np.float64)

for t in range(T):
    for i in range(size):
        labels[i,t] = anm[i + H + t]

split = size // 10      
shuffle = np.random.permutation(size)
train_ind = np.array(shuffle[0: 8 * split])
val_ind = np.array(shuffle[8 * split: 9 * split])
test_ind = np.array(shuffle[9 * split: size])

train = np.array(data[train_ind])
train_labels = np.array(labels[train_ind])

val = np.array(data[val_ind])
val_labels = np.array(labels[val_ind])

test = np.array(data[test_ind])
test_labels = np.array(labels[test_ind])

plt.hist(train_labels, bins=50);

# %%
(N1, N2, N3, d) = (192, 768, 768, 0.5)
epochs = 40

model = tf.keras.models.Sequential([
                  tf.keras.layers.Dense(N1,  kernel_initializer='normal', activation = tf.nn.relu),
                  tf.keras.layers.Dropout(d),
                  tf.keras.layers.Dense(N2,  kernel_initializer='normal', activation = tf.nn.relu),
                  tf.keras.layers.Dropout(d),
                  tf.keras.layers.Dense(N3,  kernel_initializer='normal', activation = tf.nn.relu),
                  tf.keras.layers.Dropout(d),
                  tf.keras.layers.Dense(T,  kernel_initializer='normal', activation = 'linear')
        ])

model.reset_states()

model.compile(optimizer='adam',
                    loss='mae',
                    metrics=['mse', 'mae'])

history = model.fit(train, train_labels, epochs = epochs, verbose = 1)
(loss, mse, mae) = model.evaluate(val, val_labels, verbose = 0)

print(mse, mae)
# Out:
# Epoch 1/40
# 5696/5696 [==============================] - 3s 535us/step - loss: 0.5520 - mean_squared_error: 0.5377 - mean_absolute_error: 0.5520
# Epoch 2/40
# 5696/5696 [==============================] - 2s 438us/step - loss: 0.5235 - mean_squared_error: 0.5008 - mean_absolute_error: 0.5235
# Epoch 3/40
# 5696/5696 [==============================] - 3s 484us/step - loss: 0.5172 - mean_squared_error: 0.4935 - mean_absolute_error: 0.5172
# Epoch 4/40
# 5696/5696 [==============================] - 3s 459us/step - loss: 0.5141 - mean_squared_error: 0.4905 - mean_absolute_error: 0.5141
# Epoch 5/40
# 5696/5696 [==============================] - 2s 428us/step - loss: 0.5117 - mean_squared_error: 0.4880 - mean_absolute_error: 0.5117
# Epoch 6/40
# 5696/5696 [==============================] - 3s 479us/step - loss: 0.5097 - mean_squared_error: 0.4859 - mean_absolute_error: 0.5097
# Epoch 7/40
# 5696/5696 [==============================] - 3s 449us/step - loss: 0.5081 - mean_squared_error: 0.4840 - mean_absolute_error: 0.5081
# Epoch 8/40
# 5696/5696 [==============================] - 2s 428us/step - loss: 0.5066 - mean_squared_error: 0.4823 - mean_absolute_error: 0.5066
# Epoch 9/40
# 5696/5696 [==============================] - 2s 356us/step - loss: 0.5053 - mean_squared_error: 0.4812 - mean_absolute_error: 0.5053
# Epoch 10/40
# 5696/5696 [==============================] - 2s 357us/step - loss: 0.5030 - mean_squared_error: 0.4784 - mean_absolute_error: 0.5030
# Epoch 11/40
# 5696/5696 [==============================] - 2s 356us/step - loss: 0.5011 - mean_squared_error: 0.4762 - mean_absolute_error: 0.5011
# Epoch 12/40
# 5696/5696 [==============================] - 2s 353us/step - loss: 0.4990 - mean_squared_error: 0.4735 - mean_absolute_error: 0.4990
# Epoch 13/40
# 5696/5696 [==============================] - 2s 355us/step - loss: 0.4977 - mean_squared_error: 0.4718 - mean_absolute_error: 0.4977
# Epoch 14/40
# 5696/5696 [==============================] - 2s 370us/step - loss: 0.4951 - mean_squared_error: 0.4683 - mean_absolute_error: 0.4951
# Epoch 15/40
# 5696/5696 [==============================] - 2s 357us/step - loss: 0.4937 - mean_squared_error: 0.4668 - mean_absolute_error: 0.4937
# Epoch 16/40
# 5696/5696 [==============================] - 2s 359us/step - loss: 0.4913 - mean_squared_error: 0.4637 - mean_absolute_error: 0.4913
# Epoch 17/40
# 5696/5696 [==============================] - 2s 353us/step - loss: 0.4882 - mean_squared_error: 0.4593 - mean_absolute_error: 0.4882
# Epoch 18/40
# 5696/5696 [==============================] - 2s 359us/step - loss: 0.4862 - mean_squared_error: 0.4571 - mean_absolute_error: 0.4862
# Epoch 19/40
# 5696/5696 [==============================] - 2s 355us/step - loss: 0.4841 - mean_squared_error: 0.4541 - mean_absolute_error: 0.4841
# Epoch 20/40
# 5696/5696 [==============================] - 2s 355us/step - loss: 0.4823 - mean_squared_error: 0.4512 - mean_absolute_error: 0.4823
# Epoch 21/40
# 5696/5696 [==============================] - 2s 358us/step - loss: 0.4796 - mean_squared_error: 0.4477 - mean_absolute_error: 0.4796
# Epoch 22/40
# 5696/5696 [==============================] - 2s 361us/step - loss: 0.4764 - mean_squared_error: 0.4433 - mean_absolute_error: 0.4764
# Epoch 23/40
# 5696/5696 [==============================] - 2s 357us/step - loss: 0.4742 - mean_squared_error: 0.4406 - mean_absolute_error: 0.4742
# Epoch 24/40
# 5696/5696 [==============================] - 2s 358us/step - loss: 0.4715 - mean_squared_error: 0.4366 - mean_absolute_error: 0.4715
# Epoch 25/40
# 5696/5696 [==============================] - 2s 358us/step - loss: 0.4686 - mean_squared_error: 0.4326 - mean_absolute_error: 0.4686
# Epoch 26/40
# 5696/5696 [==============================] - 2s 374us/step - loss: 0.4653 - mean_squared_error: 0.4281 - mean_absolute_error: 0.4653
# Epoch 27/40
# 5696/5696 [==============================] - 2s 378us/step - loss: 0.4624 - mean_squared_error: 0.4244 - mean_absolute_error: 0.4624
# Epoch 28/40
# 5696/5696 [==============================] - 2s 369us/step - loss: 0.4592 - mean_squared_error: 0.4198 - mean_absolute_error: 0.4592
# Epoch 29/40
# 5696/5696 [==============================] - 2s 359us/step - loss: 0.4560 - mean_squared_error: 0.4153 - mean_absolute_error: 0.4560
# Epoch 30/40
# 5696/5696 [==============================] - 2s 355us/step - loss: 0.4526 - mean_squared_error: 0.4106 - mean_absolute_error: 0.4526
# Epoch 31/40
# 5696/5696 [==============================] - 2s 364us/step - loss: 0.4500 - mean_squared_error: 0.4070 - mean_absolute_error: 0.4500
# Epoch 32/40
# 5696/5696 [==============================] - 2s 359us/step - loss: 0.4472 - mean_squared_error: 0.4020 - mean_absolute_error: 0.4472
# Epoch 33/40
# 5696/5696 [==============================] - 2s 359us/step - loss: 0.4424 - mean_squared_error: 0.3955 - mean_absolute_error: 0.4424
# Epoch 34/40
# 5696/5696 [==============================] - 2s 385us/step - loss: 0.4398 - mean_squared_error: 0.3922 - mean_absolute_error: 0.4398
# Epoch 35/40
# 5696/5696 [==============================] - 3s 551us/step - loss: 0.4362 - mean_squared_error: 0.3864 - mean_absolute_error: 0.4362
# Epoch 36/40
# 5696/5696 [==============================] - 3s 542us/step - loss: 0.4324 - mean_squared_error: 0.3809 - mean_absolute_error: 0.4324
# Epoch 37/40
# 5696/5696 [==============================] - 3s 523us/step - loss: 0.4288 - mean_squared_error: 0.3762 - mean_absolute_error: 0.4288
# Epoch 38/40
# 5696/5696 [==============================] - 3s 477us/step - loss: 0.4249 - mean_squared_error: 0.3706 - mean_absolute_error: 0.4249
# Epoch 39/40
# 5696/5696 [==============================] - 3s 515us/step - loss: 0.4209 - mean_squared_error: 0.3646 - mean_absolute_error: 0.4209
# Epoch 40/40
# 5696/5696 [==============================] - 3s 507us/step - loss: 0.4179 - mean_squared_error: 0.3611 - mean_absolute_error: 0.4179
# 0.4940508429923754 0.5058590521973171

# %%
plt.plot(history.history['mean_squared_error'], label = "mse");
plt.plot(history.history['mean_absolute_error'], label = "mae");
plt.legend();
plt.ylabel('error');
plt.xlabel('epoch');

# %%
pred_val = model.predict(val)

# %%
plt.hist2d(val_labels[:,-1], pred_val[:,-1], cmap = plt.cm.Spectral, vmax = 50);
plt.colorbar();

# %%
def correlation(x, y):
    x0 = x - np.mean(x, axis = 0)
    y0 = y - np.mean(y, axis = 0)
    return np.mean(x0 * y0, axis = 0) / np.sqrt((np.mean(x0**2, axis = 0) * (np.mean(y0**2, axis = 0))))

# %%
auto = np.zeros(T)
rms = np.zeros(T)

for t in range(T):
    auto[t] = correlation(anm[:(- t - 1)], anm[(t + 1):])
    rms[t] = mean_squared_error(anm[:(- t - 1)], anm[(t + 1):])
    
pred_rms_val = np.sqrt(((val_labels - pred_val)**2).mean(axis = 0))

plt.plot(auto, label = "autocorrelation");
plt.plot(correlation(val_labels, pred_val), label = "correlation of prediction");
plt.legend();
plt.figure();
plt.plot(rms, label = "data");
plt.plot(pred_rms_val, label = "rms of predictions")
plt.legend();

# %%
plt.plot(correlation(val_labels, pred_val));

# %%
plt.plot(pred_rms_val);

# %% [markdown]
# # Performance on real data

# %%
datapath = 'om_nino34_monthly.nc'
nino34 = xarray.open_dataset(datapath, decode_times = False)
nino34 = np.array((nino34['nino34'].values))
# Out:
# /Users/paulag/anaconda3/lib/python3.6/site-packages/xarray/conventions.py:362: SerializationWarning: variable 'areacello' has multiple fill values {-1e+34, 1e+20}, decoding all values to NaN.
#   stack_char_dim=stack_char_dim)

# %%
clm = climatology(nino34)
anm = SST_anomaly(nino34, clm)

# %%
signal = np.array(nino34)   # data used for training/testing
length = signal.shape[0]    # number of data points

mean = np.mean(signal)
std = np.std(signal)

signal = (signal - mean) / std

# %%
np.random.seed(0)

size = length - H - T       # effective dataset size
        
# create the 'history matrix'
data = np.ndarray((size, H + extra_features))
for i in range(size):
    data[i, 0:H] = signal[i:(i + H)]
    data[i, H] = np.mean(signal[i:(i + 6)])
    data[i, H+1] = np.mean(signal[i:(i + 6 * 2)])
    data[i, H+2] = np.mean(signal[i:(i + 6 * 4)])
    data[i, H+3] = ((i + H) % 12 - np.mean(range(12))) / np.std(range(12))

labels = np.ndarray((size, T), dtype = np.float64)

for t in range(T):
    for i in range(size):
        labels[i,t] = anm[i + H + t]

# %%
pred = model.predict(data)

# %%
plt.hist2d(labels[:,-1], pred[:,-1], cmap = plt.cm.Spectral, vmax = 30);
plt.colorbar();

# %%
auto = np.zeros(T)
rms = np.zeros(T)

for t in range(T):
    auto[t] = correlation(anm[:(- t - 1)], anm[(t + 1):])
    rms[t] = mean_squared_error(anm[:(- t - 1)], anm[(t + 1):])
    
pred_rms = np.sqrt(((labels - pred)**2).mean(axis = 0))

plt.plot(auto, label = "autocorrelation");
plt.plot(correlation(labels, pred), label = "correlation of prediction");
plt.legend();
plt.figure();
plt.plot(rms, label = "data");
plt.plot(pred_rms, label = "rms of predictions")
plt.legend();

# %%
plt.plot(correlation(val_labels, pred_val), label = "validation");
plt.plot(correlation(labels, pred), label = "real data");
plt.legend();

# %%
plt.plot(pred_rms_val, label = "validation");
plt.plot(pred_rms, label = "real data");
plt.legend();
