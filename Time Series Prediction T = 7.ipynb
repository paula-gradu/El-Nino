# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas
import xarray
import cftime
import tensorflow as tf
# Out:
# /Users/paulag/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
datapath = 'nino34_monthly.nc'
nino34 = xarray.open_dataset(datapath, decode_times = False)
print(nino34)
nino34 = np.array((nino34['nino34'].values)[12 * 50:])
# Out:
# <xarray.Dataset>
# Dimensions:         (bounds: 2, month: 12, time: 7800)
# Coordinates:
#   * time            (time) float64 15.5 45.0 74.5 ... 2.372e+05 2.372e+05
# Dimensions without coordinates: bounds, month
# Data variables:
#     nino34          (time) float64 ...
#     time_bnds       (time, bounds) float64 ...
#     areacello       float32 ...
#     days_per_month  (month) int32 ...

# %%
plt.plot(nino34[::12]);

# %%
def ONI(nino34, m = 3):
    oni = np.array(nino34)
    length = nino34.shape[0]
    for i in range(length):
        oni[i] = np.mean(nino34[max(0, (i - m + 1)) : min((i + 1), length)])
    return oni

# %%
oni = ONI(nino34)

# %%
def climatology(nino34):
    clm = np.zeros(12)
    length = nino34.shape[0]
    for month in range(12):
        section = [12 * i + month for i in range(length // 12)]
        clm[month] = np.mean(nino34[section])
    return clm

# %%
clm = climatology(nino34)

# %%
def SST_anomaly(nino34, clm):
    anm = np.array(nino34)
    length = nino34.shape[0]
    for i in range(length):
        anm[i] = nino34[i] - clm[i % 12]
    return anm

# %%
anm = SST_anomaly(nino34, clm)
oanm = ONI(anm)

# %% [markdown]
# # Data Preparation

# %%
T = 7      # prediction timeline
H = 48   # history used for prediction
include_month = 1           # 1 if we use the month as a feature, 0 otherwise
threshold = 0.5         
signal = np.array(nino34)   # data used for training/testing
length = signal.shape[0]    # number of data points

mean = np.mean(signal)
std = np.std(signal)

signal = (signal - mean) / std

# %%
np.random.seed(0)

size = length - H - T       # effective dataset size
        
# create the 'history matrix'
data = np.ndarray((size, H + include_month))
for i in range(size):
    if(include_month == False):
         data[i] = signal[i:(i + H)]
    else:
        data[i] = np.append(signal[i:(i + H)], (i + H + T) % 12)

labels = np.ndarray((size), dtype = np.float64)
        
for i in range(size):
    labels[i] = anm[i + H + T]

split = size // 10      
shuffle = np.random.permutation(size)
train_ind = np.array(shuffle[0: 8 * split])
val_ind = np.array(shuffle[8 * split: 9 * split])
test_ind = np.array(shuffle[9 * split: size])

train = np.array(data[train_ind])
train_labels = np.array(labels[train_ind])

val = np.array(data[val_ind])
val_labels = np.array(labels[val_ind])

test = np.array(data[test_ind])
test_labels = np.array(labels[test_ind])

# %%
plt.hist(train_labels, bins=50);

# %% [markdown]
# # Simple Model

# %%
mse = {}
mae = {}

for N1 in [H * 4, H * 8, H * 16]:
    for N2 in [H * 8, H * 16]:
        for N3 in [H * 8, H * 16, H * 32]:
            for d in [0, 0.2, 0.5]:
                for e in [50, 60, 70]:
                    model = tf.keras.models.Sequential([
                      tf.keras.layers.Dense(N1,  kernel_initializer='normal', activation = tf.nn.relu),
                      tf.keras.layers.Dropout(d),
                      tf.keras.layers.Dense(N2,  kernel_initializer='normal', activation = tf.nn.relu),
                      tf.keras.layers.Dropout(d),
                      tf.keras.layers.Dense(N3,  kernel_initializer='normal', activation = tf.nn.relu),
                      tf.keras.layers.Dropout(d),
                      tf.keras.layers.Dense(1,  kernel_initializer='normal', activation = 'linear')
                    ])

                    model.reset_states()

                    model.compile(optimizer='adam',
                        loss='mae',
                        metrics=['mse', 'mae'])

                    model.fit(train_n, train_labels, epochs = e, verbose = 0)
                    (loss, mse[(N1, N2, N3, d, e)], mae[(N1, N2, N3, d, e)]) = model.evaluate(val_n, val_labels, verbose = 0)
    
                    print(N1, N2, N3, d, e, mse[(N1, N2, N3, d, e)], mae[(N1, N2, N3, d, e)])

# %%
best_models = {k:v for (k,v) in mse.items() if v < 0.3}
print(best_models)
# Out:
# {}

# %%
(N1, N2, N3, d) = (192, 768, 768, 0.5)
epochs = 60

model = tf.keras.models.Sequential([
                  tf.keras.layers.Dense(N1,  kernel_initializer='normal', activation = tf.nn.relu),
                  tf.keras.layers.Dropout(d),
                  tf.keras.layers.Dense(N2,  kernel_initializer='normal', activation = tf.nn.relu),
                  tf.keras.layers.Dropout(d),
                  tf.keras.layers.Dense(N3,  kernel_initializer='normal', activation = tf.nn.relu),
                  tf.keras.layers.Dropout(d),
                  tf.keras.layers.Dense(1,  kernel_initializer='normal', activation = 'linear')
        ])

model.reset_states()

model.compile(optimizer='adam',
                    loss='mae',
                    metrics=['mse', 'mae'])

model.fit(train, train_labels, epochs = epochs, verbose = 1)
(loss, mse, mae) = model.evaluate(val, val_labels, verbose = 0)

print(mse, mae)
# Out:
# Epoch 1/60
# 5712/5712 [==============================] - 17s 3ms/step - loss: 0.6280 - mean_squared_error: 0.6531 - mean_absolute_error: 0.6280
# Epoch 2/60
# 5712/5712 [==============================] - 4s 626us/step - loss: 0.5901 - mean_squared_error: 0.5834 - mean_absolute_error: 0.5901
# Epoch 3/60
# 5712/5712 [==============================] - 4s 617us/step - loss: 0.5721 - mean_squared_error: 0.5564 - mean_absolute_error: 0.5721
# Epoch 4/60
# 5712/5712 [==============================] - 3s 486us/step - loss: 0.5600 - mean_squared_error: 0.5409 - mean_absolute_error: 0.5600
# Epoch 5/60
# 5712/5712 [==============================] - 3s 488us/step - loss: 0.5522 - mean_squared_error: 0.5306 - mean_absolute_error: 0.5522
# Epoch 6/60
# 5712/5712 [==============================] - 3s 497us/step - loss: 0.5428 - mean_squared_error: 0.5130 - mean_absolute_error: 0.5428
# Epoch 7/60
# 5712/5712 [==============================] - 3s 472us/step - loss: 0.5283 - mean_squared_error: 0.4986 - mean_absolute_error: 0.5283
# Epoch 8/60
# 5712/5712 [==============================] - 3s 510us/step - loss: 0.5193 - mean_squared_error: 0.4836 - mean_absolute_error: 0.5193
# Epoch 9/60
# 5712/5712 [==============================] - 3s 506us/step - loss: 0.5073 - mean_squared_error: 0.4639 - mean_absolute_error: 0.5073
# Epoch 10/60
# 5712/5712 [==============================] - 4s 659us/step - loss: 0.4973 - mean_squared_error: 0.4551 - mean_absolute_error: 0.4973
# Epoch 11/60
# 5712/5712 [==============================] - 3s 518us/step - loss: 0.4802 - mean_squared_error: 0.4282 - mean_absolute_error: 0.4802
# Epoch 12/60
# 5712/5712 [==============================] - 3s 485us/step - loss: 0.4690 - mean_squared_error: 0.4174 - mean_absolute_error: 0.4690
# Epoch 13/60
# 5712/5712 [==============================] - 3s 480us/step - loss: 0.4536 - mean_squared_error: 0.3927 - mean_absolute_error: 0.4536
# Epoch 14/60
# 5712/5712 [==============================] - 3s 476us/step - loss: 0.4449 - mean_squared_error: 0.3819 - mean_absolute_error: 0.4449
# Epoch 15/60
# 5712/5712 [==============================] - 3s 482us/step - loss: 0.4290 - mean_squared_error: 0.3599 - mean_absolute_error: 0.4290
# Epoch 16/60
# 5712/5712 [==============================] - 3s 503us/step - loss: 0.4130 - mean_squared_error: 0.3426 - mean_absolute_error: 0.4130
# Epoch 17/60
# 5712/5712 [==============================] - 3s 486us/step - loss: 0.4030 - mean_squared_error: 0.3264 - mean_absolute_error: 0.4030
# Epoch 18/60
# 5712/5712 [==============================] - 3s 510us/step - loss: 0.3872 - mean_squared_error: 0.3063 - mean_absolute_error: 0.3872
# Epoch 19/60
# 5712/5712 [==============================] - 3s 519us/step - loss: 0.3718 - mean_squared_error: 0.2849 - mean_absolute_error: 0.3718
# Epoch 20/60
# 5712/5712 [==============================] - 3s 484us/step - loss: 0.3582 - mean_squared_error: 0.2633 - mean_absolute_error: 0.3582
# Epoch 21/60
# 5712/5712 [==============================] - 3s 484us/step - loss: 0.3424 - mean_squared_error: 0.2438 - mean_absolute_error: 0.3424
# Epoch 22/60
# 5712/5712 [==============================] - 3s 466us/step - loss: 0.3262 - mean_squared_error: 0.2225 - mean_absolute_error: 0.3262
# Epoch 23/60
# 5712/5712 [==============================] - 3s 466us/step - loss: 0.3120 - mean_squared_error: 0.2083 - mean_absolute_error: 0.3120
# Epoch 24/60
# 5712/5712 [==============================] - 3s 482us/step - loss: 0.3027 - mean_squared_error: 0.1977 - mean_absolute_error: 0.3027
# Epoch 25/60
# 5712/5712 [==============================] - 3s 570us/step - loss: 0.2863 - mean_squared_error: 0.1723 - mean_absolute_error: 0.2863
# Epoch 26/60
# 5712/5712 [==============================] - 3s 534us/step - loss: 0.2774 - mean_squared_error: 0.1597 - mean_absolute_error: 0.2774
# Epoch 27/60
# 5712/5712 [==============================] - 3s 492us/step - loss: 0.2628 - mean_squared_error: 0.1497 - mean_absolute_error: 0.2628
# Epoch 28/60
# 5712/5712 [==============================] - 3s 524us/step - loss: 0.2519 - mean_squared_error: 0.1377 - mean_absolute_error: 0.2519
# Epoch 29/60
# 5712/5712 [==============================] - 3s 479us/step - loss: 0.2465 - mean_squared_error: 0.1311 - mean_absolute_error: 0.2465
# Epoch 30/60
# 5712/5712 [==============================] - 3s 489us/step - loss: 0.2349 - mean_squared_error: 0.1208 - mean_absolute_error: 0.2349
# Epoch 31/60
# 5712/5712 [==============================] - 3s 494us/step - loss: 0.2315 - mean_squared_error: 0.1132 - mean_absolute_error: 0.2315
# Epoch 32/60
# 5712/5712 [==============================] - 3s 493us/step - loss: 0.2230 - mean_squared_error: 0.1039 - mean_absolute_error: 0.2230
# Epoch 33/60
# 5712/5712 [==============================] - 3s 488us/step - loss: 0.2131 - mean_squared_error: 0.0942 - mean_absolute_error: 0.2131
# Epoch 34/60
# 5712/5712 [==============================] - 3s 483us/step - loss: 0.2071 - mean_squared_error: 0.0873 - mean_absolute_error: 0.2071
# Epoch 35/60
# 5712/5712 [==============================] - 3s 485us/step - loss: 0.2014 - mean_squared_error: 0.0824 - mean_absolute_error: 0.2014
# Epoch 36/60
# 5712/5712 [==============================] - 3s 487us/step - loss: 0.1935 - mean_squared_error: 0.0785 - mean_absolute_error: 0.1935
# Epoch 37/60
# 5712/5712 [==============================] - 3s 489us/step - loss: 0.1899 - mean_squared_error: 0.0734 - mean_absolute_error: 0.1899
# Epoch 38/60
# 5712/5712 [==============================] - 3s 502us/step - loss: 0.1838 - mean_squared_error: 0.0700 - mean_absolute_error: 0.1838
# Epoch 39/60
# 5712/5712 [==============================] - 3s 478us/step - loss: 0.1790 - mean_squared_error: 0.0660 - mean_absolute_error: 0.1790
# Epoch 40/60
# 5712/5712 [==============================] - 3s 490us/step - loss: 0.1721 - mean_squared_error: 0.0612 - mean_absolute_error: 0.1721
# Epoch 41/60
# 5712/5712 [==============================] - 3s 487us/step - loss: 0.1703 - mean_squared_error: 0.0586 - mean_absolute_error: 0.1703
# Epoch 42/60
# 5712/5712 [==============================] - 3s 470us/step - loss: 0.1656 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1656
# Epoch 43/60
# 5712/5712 [==============================] - 3s 500us/step - loss: 0.1635 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1635
# Epoch 44/60
# 5712/5712 [==============================] - 3s 506us/step - loss: 0.1612 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1612
# Epoch 45/60
# 5712/5712 [==============================] - 3s 541us/step - loss: 0.1550 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1550
# Epoch 46/60
# 5712/5712 [==============================] - 3s 561us/step - loss: 0.1523 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1523
# Epoch 47/60
# 5712/5712 [==============================] - 3s 481us/step - loss: 0.1525 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1525
# Epoch 48/60
# 5712/5712 [==============================] - 3s 510us/step - loss: 0.1474 - mean_squared_error: 0.0430 - mean_absolute_error: 0.1474
# Epoch 49/60
# 5712/5712 [==============================] - 4s 640us/step - loss: 0.1477 - mean_squared_error: 0.0421 - mean_absolute_error: 0.1477
# Epoch 50/60
# 5712/5712 [==============================] - 4s 683us/step - loss: 0.1424 - mean_squared_error: 0.0388 - mean_absolute_error: 0.1424
# Epoch 51/60
# 5712/5712 [==============================] - 4s 648us/step - loss: 0.1407 - mean_squared_error: 0.0377 - mean_absolute_error: 0.1407
# Epoch 52/60
# 5712/5712 [==============================] - 3s 599us/step - loss: 0.1422 - mean_squared_error: 0.0389 - mean_absolute_error: 0.1422
# Epoch 53/60
# 5712/5712 [==============================] - 4s 683us/step - loss: 0.1408 - mean_squared_error: 0.0383 - mean_absolute_error: 0.1408
# Epoch 54/60
# 5712/5712 [==============================] - 4s 638us/step - loss: 0.1365 - mean_squared_error: 0.0359 - mean_absolute_error: 0.1365
# Epoch 55/60
# 5712/5712 [==============================] - 4s 652us/step - loss: 0.1359 - mean_squared_error: 0.0361 - mean_absolute_error: 0.1359
# Epoch 56/60
# 5712/5712 [==============================] - 3s 538us/step - loss: 0.1316 - mean_squared_error: 0.0329 - mean_absolute_error: 0.1316
# Epoch 57/60
# 5712/5712 [==============================] - 3s 565us/step - loss: 0.1319 - mean_squared_error: 0.0332 - mean_absolute_error: 0.1319
# Epoch 58/60
# 5712/5712 [==============================] - 3s 503us/step - loss: 0.1288 - mean_squared_error: 0.0316 - mean_absolute_error: 0.1288
# Epoch 59/60
# 5712/5712 [==============================] - 3s 514us/step - loss: 0.1301 - mean_squared_error: 0.0323 - mean_absolute_error: 0.1301
# Epoch 60/60
# 5712/5712 [==============================] - 3s 479us/step - loss: 0.1272 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1272
# 0.29655109337564944 0.3879145360460468

# %%
pred = model.predict(train)

# %%
print(mean_squared_error(train_labels, pred))
print(mean_absolute_error(train_labels, pred))
# Out:
# 0.03144587866347687
# 0.12850134691938953

# %%
plt.hist2d(train_labels, pred[:,0], cmap = plt.cm.Spectral, vmax = 200);
plt.colorbar();

# %%
plt.plot(train_labels, pred[:,0], ".");

# %%
pred_val = model.predict(val)

# %%
plt.hist2d(val_labels, pred_val[:,0], cmap = plt.cm.Spectral, vmax = 50);
plt.colorbar();

# %%
plt.plot(val_labels, pred_val[:,0], ".");

# %%
def correlation(x, y):
    x0 = x - np.mean(x)
    y0 = y - np.mean(y)
    return np.mean(x0 * y0) / np.sqrt((np.mean(x0**2) * (np.mean(y0**2))))

# %%
print(correlation(train_labels, pred[:,0]))
print(correlation(val_labels, pred_val[:,0]))
# Out:
# 0.9771649717103147
# 0.7508694888500023

# %% [markdown]
# # Simple Regressors

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

model = RandomForestRegressor()
model.fit(train,train_labels)

# Get the mean absolute error on the validation data
predicted = model.predict(val)
MAE = mean_absolute_error(val_labels , predicted)
MSE = mean_squared_error(val_labels , predicted)
print(MAE, MSE)
# Out:
# 0.6126002018123262 0.6137351921972332

# %%
plt.plot(anm[train_ind + H + T], model.predict(train), ".");

# %%
plt.hist2d(anm[train_ind + H + T], model.predict(train), cmap = plt.cm.Spectral, vmax = 500);

# %%
plt.plot(anm[val_ind + H + T], model.predict(val), ".");

# %%
plt.hist2d(anm[val_ind + H + T], model.predict(val), cmap = plt.cm.Spectral, vmax = 50);

# %%
from sklearn import svm

model = svm.SVR()
model.fit(train,train_labels)

predicted = model.predict(val)
MAE = mean_absolute_error(val_labels , predicted)
MSE = mean_squared_error(val_labels , predicted)

print(MAE, MSE)
# Out:
# 0.5763728936509528 0.5637201328824797

# %%
plt.plot(anm[train_ind + H + T], model.predict(train), ".");

# %%
plt.hist2d(anm[train_ind + H + T], model.predict(train), cmap = plt.cm.Spectral, vmax = 500);
plt.colorbar();

# %%
plt.plot(anm[val_ind + H + T], model.predict(val), ".");

# %%
plt.hist2d(anm[val_ind + H + T], model.predict(val), cmap = plt.cm.Spectral, vmax = 50);
